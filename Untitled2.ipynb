# %% [markdown]
# <a href="https://colab.research.google.com/github/biplabp455/Skill-Morph-ML-Training/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello! Welcome to Skill Morph")
# Out:
# Hello! Welcome to Skill Morph
